# %% [markdown]
# ## Session 4 · Framework Practice — the Student Data (Python)
#
# **Dataset:** `Y1_T1_2025.xlsx` (sheet `Extract`) — the Term 1 student unit-attempt
# extract you met in Session 3.
#
# This is deliberate repetition: run the **whole six-stage flow** again on a different
# dataset, with fewer prompts. Import → Clean → Transform → Explore → Visualise →
# Interpret. Fill in each step yourself.

# %% [markdown]
# ### 1. Import
#
# Read the `Extract` sheet into `df` and print its shape and columns.

# %%
import pandas as pd
from pathlib import Path

DATA_FOLDER = Path("data")
DATA_FILE = DATA_FOLDER / "Y1_T1_2025.xlsx"

# TODO: read the "Extract" sheet into df
# TODO: print df.shape and list(df.columns)

# %% [markdown]
# ### 2. Clean
#
# Check missing values. What does a missing `mark` mean here (think back to the cleaning session)?

# %%
# TODO: print df.isna().sum() for a few key columns (mark, grade_code, unit_attempt_status)

# %% [markdown]
# ### 3. Transform
#
# Derive a simple `passed` column: True when `unit_attempt_status` is the pass label. First print the unique statuses to find the right label, then build the column and check its value counts.

# %%
# TODO: inspect df["unit_attempt_status"].unique()
# TODO: create df["passed"] as a boolean from unit_attempt_status

# %% [markdown]
# ### 4. Explore
#
# Count `program_code`, cross-tab `program_code` against `unit_attempt_status` as **row percentages**, and `describe()` the `mark`.

# %%
# TODO: value_counts of program_code
# TODO: row-percentage crosstab of program_code vs unit_attempt_status
# TODO: describe() of mark

# %% [markdown]
# ### 5. Visualise
#
# Set up seaborn. Draw a histogram of `mark`, and a box plot of `mark` split by `international_flag`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
# TODO: histplot of mark
# TODO: boxplot of mark by international_flag

# %% [markdown]
# ### 6. Interpret
#
# Write 3–4 sentences of findings about the student cohort, exactly as you did for
# the 1500m data. Note which stage of the flow took the most effort this time, and
# whether the framework felt more automatic the second time through.
