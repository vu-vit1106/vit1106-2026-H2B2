# %% [markdown]
# # Solution: Introduction to dataframes

# %%
student_table = {
    "student": ["Taylor Nguyen", "Mia Chen", "Jordan Lee"],
    "campus": ["Footscray", "City", "Footscray"],
    "score": [82, 74, 46]
}

import pandas as pd
import numpy as np

# %%
student_scores = pd.Series([78, 45, 92], index=["Taylor Nguyen", "Mia Chen", "Jordan Lee"], name="score")
student_scores

# %%
df_students = pd.DataFrame(student_table)
df_students

# %%
df_students[["student", "campus"]]

# %%
df_students.iloc[2]

# %%
df_students[df_students["campus"] == "Footscray"]

# %%
df_students["course"] = "VIT1106"
df_students

# %%
df_students.sort_values("score", ascending=False)
